# %% [markdown]
# # The Emissions Story
#
# Lately there has been a lot of chatter about emissions and their impact on the environment. The main culprit we hear in the news is CO2. Being someone who lives in a province that has a huge chunk of its economic activity in the business of fossil fuels production, I am examining the emissions data to understand if indeed CO2 should be our focus.

# %%
# Import the necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set
# Out:
# <function seaborn.rcmod.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=True, rc=None)>

# %% [markdown]
# ## Exploring the data

# %%
# Read data files

ghg_data = pd.read_csv('greenhouse-gas-emissions-by-gas.csv')
ghg_pot = pd.read_csv('global-warming-potential-of-greenhouse-gases-over-100-year-timescale-gwp.csv')

# %%
# Get some basic information about the data we have

print(ghg_data.info())
ghg_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13291 entries, 0 to 13290
# Data columns (total 9 columns):
# Entity                           13291 non-null object
# Code                             10805 non-null object
# Year                             13291 non-null int64
# SF₆ gases (tonnes)               709 non-null float64
# PFC gases (tonnes)               704 non-null float64
# HFC gases (tonnes)               703 non-null float64
# Nitrous oxide (N₂O) (tonnes)     10757 non-null float64
# Methane (CH₄) (tonnes)           10714 non-null float64
# Carbon Dioxide (CO₂) (tonnes)    12255 non-null float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 934.6+ KB
# None
#         Entity Code  Year  SF₆ gases (tonnes)  PFC gases (tonnes)  \
# 0  Afghanistan  AFG  1960                 NaN                 NaN
# 1  Afghanistan  AFG  1961                 NaN                 NaN
# 2  Afghanistan  AFG  1962                 NaN                 NaN
# 3  Afghanistan  AFG  1963                 NaN                 NaN
# 4  Afghanistan  AFG  1964                 NaN                 NaN
#
#    HFC gases (tonnes)  Nitrous oxide (N₂O) (tonnes)  Methane (CH₄) (tonnes)  \
# 0                 NaN                           NaN                     NaN
# 1                 NaN                           NaN                     NaN
# 2                 NaN                           NaN                     NaN
# 3                 NaN                           NaN                     NaN
# 4                 NaN                           NaN                     NaN
#
#    Carbon Dioxide (CO₂) (tonnes)
# 0                       414371.0
# 1                       491378.0
# 2                       689396.0
# 3                       707731.0
# 4                       839743.0

# %%
ghg_data.describe()
# Out:
#                Year  SF₆ gases (tonnes)  PFC gases (tonnes)  \
# count  13291.000000        7.090000e+02        7.040000e+02
# mean    1987.936875        2.888988e+06        1.560128e+06
# std       15.536907        1.351229e+07        6.400114e+06
# min     1960.000000        0.000000e+00        0.000000e+00
# 25%     1975.000000        0.000000e+00        0.000000e+00
# 50%     1988.000000        0.000000e+00        0.000000e+00
# 75%     2001.000000        3.860000e+05        3.166250e+05
# max     2014.000000        1.749054e+08        7.862231e+07
#
#        HFC gases (tonnes)  Nitrous oxide (N₂O) (tonnes)  \
# count        7.030000e+02                  1.075700e+04
# mean         1.164605e+07                  1.114287e+08
# std          6.074958e+07                  3.237475e+08
# min          0.000000e+00                  0.000000e+00
# 25%          0.000000e+00                  5.255120e+05
# 50%          2.230000e+04                  4.349734e+06
# 75%          7.685000e+05                  2.849036e+07
# max          8.343456e+08                  3.260053e+09
#
#        Methane (CH₄) (tonnes)  Carbon Dioxide (CO₂) (tonnes)
# count            1.071400e+04                   1.225500e+04
# mean             2.643075e+08                   7.359938e+08
# std              8.034465e+08                   2.617749e+09
# min              0.000000e+00                  -8.067400e+04
# 25%              1.629290e+06                   9.644210e+05
# 50%              9.848605e+06                   1.146304e+07
# 75%              6.994472e+07                   1.431071e+08
# max              8.014067e+09                   3.613828e+10

# %%
# Rename the columns names
ghg_data.rename(columns = {'SF₆ gases (tonnes)':'SF6', 'PFC gases (tonnes)':'PFC', 'HFC gases (tonnes)':'HFC', 
                           'Nitrous oxide (N₂O) (tonnes)':'N2O', 'Methane (CH₄) (tonnes)':'CH4', 
                           'Carbon Dioxide (CO₂) (tonnes)':'CO2'}, inplace = True)

# %%
# Check how many NaN values in each column
ghg_data.isna().sum()
# Out:
# Entity                               0
# Code                              2486
# Year                                 0
# SF₆ gases (tonnes)               12582
# PFC gases (tonnes)               12587
# HFC gases (tonnes)               12588
# Nitrous oxide (N₂O) (tonnes)      2534
# Methane (CH₄) (tonnes)            2577
# Carbon Dioxide (CO₂) (tonnes)     1036
# dtype: int64

# %% [markdown]
# Let's examine the code column for the missing values and correct them

# %%
code_isna = ghg_data[ghg_data['Code'].isna()]

# Get unique values of the entities to understand the nature of the values
code_isna['Entity'].unique()
# Out:
# array(['Arab World', 'Caribbean small states',
#        'Central Europe and the Baltics', 'Early-demographic dividend',
#        'East Asia & Pacific', 'East Asia & Pacific (IDA & IBRD)',
#        'East Asia & Pacific (excluding high income)', 'Euro area',
#        'Europe & Central Asia', 'Europe & Central Asia (IDA & IBRD)',
#        'Europe & Central Asia (excluding high income)', 'European Union',
#        'Fragile and conflict affected situations',
#        'Heavily indebted poor countries (HIPC)', 'High income',
#        'IBRD only', 'IDA & IBRD total', 'IDA blend', 'IDA only',
#        'IDA total', 'Late-demographic dividend',
#        'Latin America & Caribbean',
#        'Latin America & Caribbean (IDA & IBRD)',
#        'Latin America & Caribbean (excluding high income)',
#        'Least developed countries: UN classification',
#        'Low & middle income', 'Low income', 'Lower middle income',
#        'Middle East & North Africa',
#        'Middle East & North Africa (IDA & IBRD)',
#        'Middle East & North Africa (excluding high income)',
#        'Middle income', 'North America', 'OECD members',
#        'Other small states', 'Pacific island small states',
#        'Post-demographic dividend', 'Pre-demographic dividend',
#        'Small states', 'South Asia', 'South Asia (IDA & IBRD)',
#        'Sub-Saharan Africa', 'Sub-Saharan Africa (IDA & IBRD)',
#        'Sub-Saharan Africa (excluding high income)',
#        'Syrian Arab Republic', 'Upper middle income'], dtype=object)

# %% [markdown]
# The values include various subsets of the total based on categories such as regions, income levels, level of development. Since we don't need these right now, they would be dropped from the main GHG data.

# %%
ghg_data.dropna(subset = ['Code'], inplace = True, axis = 0)
#ghg_data[ghg_data['Code'].isna()]
# Out:
# Entity                           0.0
# Code                             0.0
# Year                             0.0
# SF₆ gases (tonnes)               0.0
# PFC gases (tonnes)               0.0
# HFC gases (tonnes)               0.0
# Nitrous oxide (N₂O) (tonnes)     0.0
# Methane (CH₄) (tonnes)           0.0
# Carbon Dioxide (CO₂) (tonnes)    0.0
# dtype: float64

# %% [markdown]
# There should be only countries and their GHG contributions left. Next the gasses SF6, PFC and HFC have a lost of missing data. Let's check if there is a particular reason.

# %%
ghg_data[ghg_data['SF6'].isna()]
# Out:
#             Entity Code  Year  SF6  PFC  HFC         N2O        CH4  \
# 0      Afghanistan  AFG  1960  NaN  NaN  NaN         NaN        NaN
# 1      Afghanistan  AFG  1961  NaN  NaN  NaN         NaN        NaN
# 2      Afghanistan  AFG  1962  NaN  NaN  NaN         NaN        NaN
# 3      Afghanistan  AFG  1963  NaN  NaN  NaN         NaN        NaN
# 4      Afghanistan  AFG  1964  NaN  NaN  NaN         NaN        NaN
# ...            ...  ...   ...  ...  ...  ...         ...        ...
# 13285     Zimbabwe  ZWE  2009  NaN  NaN  NaN  4192006.00  8377390.0
# 13287     Zimbabwe  ZWE  2011  NaN  NaN  NaN  4228947.77  8504705.0
# 13288     Zimbabwe  ZWE  2012  NaN  NaN  NaN  4270818.54  8588910.0
# 13289     Zimbabwe  ZWE  2013  NaN  NaN  NaN         NaN        NaN
# 13290     Zimbabwe  ZWE  2014  NaN  NaN  NaN         NaN        NaN
#
#               CO2
# 0        414371.0
# 1        491378.0
# 2        689396.0
# 3        707731.0
# 4        839743.0
# ...           ...
# 13285   5603176.0
# 13287   9563536.0
# 13288   7792375.0
# 13289  11675728.0
# 13290  12020426.0
#
# [10132 rows x 9 columns]
